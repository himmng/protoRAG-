# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 65
#      63 from langchain_core.prompts import ChatPromptTemplate
#      64 from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
# ---> 65 from langchain.chains import create_retrieval_chain
#      66 from langchain.chains.combine_documents import create_stuff_documents_chain
#      68 from langchain_community.document_loaders import (
#      69         PyPDFLoader,
#      70         TextLoader,
#    (...)     74         UnstructuredExcelLoader,
#      75 )
#
# ModuleNotFoundError: No module named 'langchain.chains'

# %%
# !pip install langchain-openai langchain-chroma langchain-text-splitters langchain-core --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
